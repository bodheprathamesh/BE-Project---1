# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("../data2.csv")

# %%
df.head()
# Out:
#    Unnamed: 0            Name        Jan        Feb        Mar        Apr  \
# 0           0      Chad Smith  179018.86  177120.88  174173.55  122734.36
# 1           1  Ronald Collins   42555.73   63249.06   40379.44   57876.43
# 2           2    Darryl Brown  135601.47  174790.03  133235.49  209354.95
# 3           3  Becky Williams  145533.08  194858.86  517763.56  587363.81
# 4           4  Jennifer Bruce  111695.66   92337.60  104144.36   89659.33
#
#          May        Jun        Jul        Aug  ...  Age  Gender  \
# 0  362590.35  365079.62  249214.28  242866.21  ...   74       1
# 1   49185.06   54559.53   51300.02  108893.08  ...   58       1
# 2  180334.22  144941.36  158670.00  480330.37  ...   23       1
# 3  194260.81  238350.12  138048.70  176593.62  ...   34       1
# 4  145544.96  235337.56  276935.12  108437.74  ...   48       0
#
#    TransactionCount  Duration  Peak Season  Before Season months  \
# 0              3273         8            0                     3
# 1              3103        21            1                     0
# 2              4770         5            1                     0
# 3               405         6            0                     3
# 4               224        11            0                     3
#
#    Months left for End of Season  AVG Sales  avg order cost    Loan Amount
# 0                              7     271315       82.894898  570652.374624
# 1                              1      60072       19.359330  212107.255479
# 2                              0     194417       40.758281  756066.371479
# 3                              1     242533      598.846914  444750.202464
# 4                              1     136020      607.232143  388170.371595
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul',
#        'Aug', 'Sept', 'Oct', 'Nov', 'Dec', 'Age', 'Gender', 'TransactionCount',
#        'Duration', 'Peak Season', 'Before Season months',
#        'Months left for End of Season', 'AVG Sales', 'avg order cost',
#        'Loan Amount'],
#       dtype='object')

# %%
df = df.drop(['Name','Peak Season','Before Season months', 'Months left for End of Season','Gender'],axis = 1)

# %%
df = df.drop(['TransactionCount','Unnamed: 0'],axis = 1)

# %%
df.columns
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct',
#        'Nov', 'Dec', 'Age', 'Duration', 'AVG Sales', 'avg order cost',
#        'Loan Amount'],
#       dtype='object')

# %%
df.head()
# Out:
#          Jan        Feb        Mar        Apr        May        Jun  \
# 0  179018.86  177120.88  174173.55  122734.36  362590.35  365079.62
# 1   42555.73   63249.06   40379.44   57876.43   49185.06   54559.53
# 2  135601.47  174790.03  133235.49  209354.95  180334.22  144941.36
# 3  145533.08  194858.86  517763.56  587363.81  194260.81  238350.12
# 4  111695.66   92337.60  104144.36   89659.33  145544.96  235337.56
#
#          Jul        Aug       Sept        Oct        Nov        Dec  Age  \
# 0  249214.28  242866.21  436012.52  262280.29  390223.58  294466.47   74
# 1   51300.02  108893.08  111362.50   43984.41   60624.84   36887.95   58
# 2  158670.00  480330.37  143541.85  131941.96  227762.95  212498.75   23
# 3  138048.70  176593.62  230162.27  137788.52  189368.18  160306.05   34
# 4  276935.12  108437.74  102481.52  127726.98  120973.45  116962.33   48
#
#    Duration  AVG Sales  avg order cost    Loan Amount
# 0         8     271315       82.894898  570652.374624
# 1        21      60072       19.359330  212107.255479
# 2         5     194417       40.758281  756066.371479
# 3         6     242533      598.846914  444750.202464
# 4        11     136020      607.232143  388170.371595

# %%
x = df.iloc[:,0:12]
y = df.iloc[:,16:17]

# %%
x
# Out:
#            Jan        Feb        Mar        Apr        May        Jun  \
# 0    179018.86  177120.88  174173.55  122734.36  362590.35  365079.62
# 1     42555.73   63249.06   40379.44   57876.43   49185.06   54559.53
# 2    135601.47  174790.03  133235.49  209354.95  180334.22  144941.36
# 3    145533.08  194858.86  517763.56  587363.81  194260.81  238350.12
# 4    111695.66   92337.60  104144.36   89659.33  145544.96  235337.56
# ..         ...        ...        ...        ...        ...        ...
# 995  139740.53  134544.51  125999.43   88232.34  309053.43  382424.13
# 996  148047.79  112337.95  125866.95  110995.54  124860.01  239777.48
# 997  231075.16  227730.31  213158.66  147007.86  145156.58  156733.46
# 998   43010.58   35606.65   59184.78   43935.51   53105.99   34996.00
# 999   53968.37   52406.45   49799.04   68230.42   69081.32   83147.59
#
#            Jul        Aug       Sept        Oct        Nov        Dec
# 0    249214.28  242866.21  436012.52  262280.29  390223.58  294466.47
# 1     51300.02  108893.08  111362.50   43984.41   60624.84   36887.95
# 2    158670.00  480330.37  143541.85  131941.96  227762.95  212498.75
# 3    138048.70  176593.62  230162.27  137788.52  189368.18  160306.05
# 4    276935.12  108437.74  102481.52  127726.98  120973.45  116962.33
# ..         ...        ...        ...        ...        ...        ...
# 995  247519.61  297059.84  378994.13  110848.59  100152.30  148495.98
# 996  279428.63  215462.67  121346.99  113491.13  168815.89  172984.17
# 997  213868.72  167817.68  175357.13  156508.09  614548.60  633177.28
# 998   44865.90   91331.10   96512.01   83445.68   91989.91   64899.35
# 999  147281.16  169784.10  122698.42   80125.68   67009.16   77747.59
#
# [1000 rows x 12 columns]

# %%
y
# Out:
#        Loan Amount
# 0    570652.374624
# 1    212107.255479
# 2    756066.371479
# 3    444750.202464
# 4    388170.371595
# ..             ...
# 995  472323.487704
# 996  634214.549493
# 997  416921.052881
# 998  121654.860277
# 999  206731.603983
#
# [1000 rows x 1 columns]

# %%
df.shape
# Out:
# (1000, 17)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)    
y_train_scaled = scaler.fit_transform(y_train)
y_test_scaled = scaler.transform(y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.optimizers import Adam

# %%
classifier = Sequential()

# %%
classifier.add(LSTM(units=50, activation='relu', input_shape=(12, 1)))
# classifier.add(Dense(128, activation = 'relu', input_dim=X_train_scaled.shape[1]))

# %%
classifier.add(Dense(50, activation = 'relu'))

# %%
classifier.add(Dense(1))

# %%
classifier.compile(optimizer='adam', loss = 'mean_squared_error', metrics=['mean_squared_error'])

# %%
from tensorflow.keras.utils import plot_model
plot_model(classifier, to_file='neural_network.png', show_shapes=True, show_layer_names=True)

# %%
import matplotlib.pyplot as plt
def visualize_model(model):
    fig, ax = plt.subplots(figsize=(12, 8))
    plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True)
    img = plt.imread('model_plot.png')
    ax.imshow(img)
    ax.axis('off')
    plt.show()

# Visualize the model
visualize_model(classifier)

# %%
classifier.fit(X_train_scaled, y_train_scaled, batch_size = 64, epochs = 64, validation_split = 0.2, verbose = 2)
# Out:
# Epoch 1/64
# 9/9 - 0s - loss: 0.3135 - mean_squared_error: 0.3135 - val_loss: 0.2934 - val_mean_squared_error: 0.2934 - 118ms/epoch - 13ms/step
# Epoch 2/64
# 9/9 - 0s - loss: 0.3151 - mean_squared_error: 0.3151 - val_loss: 0.2997 - val_mean_squared_error: 0.2997 - 71ms/epoch - 8ms/step
# Epoch 3/64
# 9/9 - 0s - loss: 0.3046 - mean_squared_error: 0.3046 - val_loss: 0.2871 - val_mean_squared_error: 0.2871 - 68ms/epoch - 8ms/step
# Epoch 4/64
# 9/9 - 0s - loss: 0.3168 - mean_squared_error: 0.3168 - val_loss: 0.3098 - val_mean_squared_error: 0.3098 - 66ms/epoch - 7ms/step
# Epoch 5/64
# 9/9 - 0s - loss: 0.3074 - mean_squared_error: 0.3074 - val_loss: 0.2865 - val_mean_squared_error: 0.2865 - 71ms/epoch - 8ms/step
# Epoch 6/64
# 9/9 - 0s - loss: 0.3032 - mean_squared_error: 0.3032 - val_loss: 0.2816 - val_mean_squared_error: 0.2816 - 100ms/epoch - 11ms/step
# Epoch 7/64
# 9/9 - 0s - loss: 0.2967 - mean_squared_error: 0.2967 - val_loss: 0.2914 - val_mean_squared_error: 0.2914 - 163ms/epoch - 18ms/step
# Epoch 8/64
# 9/9 - 0s - loss: 0.2964 - mean_squared_error: 0.2964 - val_loss: 0.2874 - val_mean_squared_error: 0.2874 - 108ms/epoch - 12ms/step
# Epoch 9/64
# 9/9 - 0s - loss: 0.3011 - mean_squared_error: 0.3011 - val_loss: 0.2980 - val_mean_squared_error: 0.2980 - 135ms/epoch - 15ms/step
# Epoch 10/64
# 9/9 - 0s - loss: 0.2947 - mean_squared_error: 0.2947 - val_loss: 0.2841 - val_mean_squared_error: 0.2841 - 141ms/epoch - 16ms/step
# Epoch 11/64
# 9/9 - 0s - loss: 0.2971 - mean_squared_error: 0.2971 - val_loss: 0.2843 - val_mean_squared_error: 0.2843 - 129ms/epoch - 14ms/step
# Epoch 12/64
# 9/9 - 0s - loss: 0.2966 - mean_squared_error: 0.2966 - val_loss: 0.3015 - val_mean_squared_error: 0.3015 - 87ms/epoch - 10ms/step
# Epoch 13/64
# 9/9 - 0s - loss: 0.2910 - mean_squared_error: 0.2910 - val_loss: 0.2886 - val_mean_squared_error: 0.2886 - 71ms/epoch - 8ms/step
# Epoch 14/64
# 9/9 - 0s - loss: 0.2992 - mean_squared_error: 0.2992 - val_loss: 0.2885 - val_mean_squared_error: 0.2885 - 71ms/epoch - 8ms/step
# Epoch 15/64
# 9/9 - 0s - loss: 0.2942 - mean_squared_error: 0.2942 - val_loss: 0.2977 - val_mean_squared_error: 0.2977 - 71ms/epoch - 8ms/step
# Epoch 16/64
# 9/9 - 0s - loss: 0.2893 - mean_squared_error: 0.2893 - val_loss: 0.2779 - val_mean_squared_error: 0.2779 - 73ms/epoch - 8ms/step
# Epoch 17/64
# 9/9 - 0s - loss: 0.2840 - mean_squared_error: 0.2840 - val_loss: 0.2844 - val_mean_squared_error: 0.2844 - 71ms/epoch - 8ms/step
# Epoch 18/64
# 9/9 - 0s - loss: 0.2849 - mean_squared_error: 0.2849 - val_loss: 0.2936 - val_mean_squared_error: 0.2936 - 83ms/epoch - 9ms/step
# Epoch 19/64
# 9/9 - 0s - loss: 0.2984 - mean_squared_error: 0.2984 - val_loss: 0.3196 - val_mean_squared_error: 0.3196 - 69ms/epoch - 8ms/step
# Epoch 20/64
# 9/9 - 0s - loss: 0.2918 - mean_squared_error: 0.2918 - val_loss: 0.2800 - val_mean_squared_error: 0.2800 - 68ms/epoch - 8ms/step
# Epoch 21/64
# 9/9 - 0s - loss: 0.2866 - mean_squared_error: 0.2866 - val_loss: 0.2832 - val_mean_squared_error: 0.2832 - 69ms/epoch - 8ms/step
# Epoch 22/64
# 9/9 - 0s - loss: 0.2816 - mean_squared_error: 0.2816 - val_loss: 0.2920 - val_mean_squared_error: 0.2920 - 69ms/epoch - 8ms/step
# Epoch 23/64
# 9/9 - 0s - loss: 0.2793 - mean_squared_error: 0.2793 - val_loss: 0.2840 - val_mean_squared_error: 0.2840 - 70ms/epoch - 8ms/step
# Epoch 24/64
# 9/9 - 0s - loss: 0.2757 - mean_squared_error: 0.2757 - val_loss: 0.2872 - val_mean_squared_error: 0.2872 - 69ms/epoch - 8ms/step
# Epoch 25/64
# 9/9 - 0s - loss: 0.2771 - mean_squared_error: 0.2771 - val_loss: 0.2932 - val_mean_squared_error: 0.2932 - 70ms/epoch - 8ms/step
# Epoch 26/64
# 9/9 - 0s - loss: 0.2772 - mean_squared_error: 0.2772 - val_loss: 0.2859 - val_mean_squared_error: 0.2859 - 70ms/epoch - 8ms/step
# Epoch 27/64
# 9/9 - 0s - loss: 0.2830 - mean_squared_error: 0.2830 - val_loss: 0.2961 - val_mean_squared_error: 0.2961 - 72ms/epoch - 8ms/step
# Epoch 28/64
# 9/9 - 0s - loss: 0.2813 - mean_squared_error: 0.2813 - val_loss: 0.2940 - val_mean_squared_error: 0.2940 - 68ms/epoch - 8ms/step
# Epoch 29/64
# 9/9 - 0s - loss: 0.2802 - mean_squared_error: 0.2802 - val_loss: 0.2887 - val_mean_squared_error: 0.2887 - 68ms/epoch - 8ms/step
# Epoch 30/64
# 9/9 - 0s - loss: 0.2752 - mean_squared_error: 0.2752 - val_loss: 0.2882 - val_mean_squared_error: 0.2882 - 69ms/epoch - 8ms/step
# Epoch 31/64
# 9/9 - 0s - loss: 0.2774 - mean_squared_error: 0.2774 - val_loss: 0.3066 - val_mean_squared_error: 0.3066 - 71ms/epoch - 8ms/step
# Epoch 32/64
# 9/9 - 0s - loss: 0.2863 - mean_squared_error: 0.2863 - val_loss: 0.3353 - val_mean_squared_error: 0.3353 - 68ms/epoch - 8ms/step
# Epoch 33/64
# 9/9 - 0s - loss: 0.2930 - mean_squared_error: 0.2930 - val_loss: 0.2828 - val_mean_squared_error: 0.2828 - 70ms/epoch - 8ms/step
# Epoch 34/64
# 9/9 - 0s - loss: 0.2808 - mean_squared_error: 0.2808 - val_loss: 0.2825 - val_mean_squared_error: 0.2825 - 71ms/epoch - 8ms/step
# Epoch 35/64
# 9/9 - 0s - loss: 0.2729 - mean_squared_error: 0.2729 - val_loss: 0.2877 - val_mean_squared_error: 0.2877 - 70ms/epoch - 8ms/step
# Epoch 36/64
# 9/9 - 0s - loss: 0.2699 - mean_squared_error: 0.2699 - val_loss: 0.2758 - val_mean_squared_error: 0.2758 - 69ms/epoch - 8ms/step
# Epoch 37/64
# 9/9 - 0s - loss: 0.2649 - mean_squared_error: 0.2649 - val_loss: 0.2892 - val_mean_squared_error: 0.2892 - 71ms/epoch - 8ms/step
# Epoch 38/64
# 9/9 - 0s - loss: 0.2661 - mean_squared_error: 0.2661 - val_loss: 0.2897 - val_mean_squared_error: 0.2897 - 71ms/epoch - 8ms/step
# Epoch 39/64
# 9/9 - 0s - loss: 0.2772 - mean_squared_error: 0.2772 - val_loss: 0.3204 - val_mean_squared_error: 0.3204 - 69ms/epoch - 8ms/step
# Epoch 40/64
# 9/9 - 0s - loss: 0.2707 - mean_squared_error: 0.2707 - val_loss: 0.2838 - val_mean_squared_error: 0.2838 - 69ms/epoch - 8ms/step
# Epoch 41/64
# 9/9 - 0s - loss: 0.2627 - mean_squared_error: 0.2627 - val_loss: 0.2811 - val_mean_squared_error: 0.2811 - 73ms/epoch - 8ms/step
# Epoch 42/64
# 9/9 - 0s - loss: 0.2682 - mean_squared_error: 0.2682 - val_loss: 0.2987 - val_mean_squared_error: 0.2987 - 70ms/epoch - 8ms/step
# Epoch 43/64
# 9/9 - 0s - loss: 0.2641 - mean_squared_error: 0.2641 - val_loss: 0.2888 - val_mean_squared_error: 0.2888 - 70ms/epoch - 8ms/step
# Epoch 44/64
# 9/9 - 0s - loss: 0.2779 - mean_squared_error: 0.2779 - val_loss: 0.3441 - val_mean_squared_error: 0.3441 - 72ms/epoch - 8ms/step
# Epoch 45/64
# 9/9 - 0s - loss: 0.2807 - mean_squared_error: 0.2807 - val_loss: 0.2924 - val_mean_squared_error: 0.2924 - 69ms/epoch - 8ms/step
# Epoch 46/64
# 9/9 - 0s - loss: 0.2648 - mean_squared_error: 0.2648 - val_loss: 0.2912 - val_mean_squared_error: 0.2912 - 109ms/epoch - 12ms/step
# Epoch 47/64
# 9/9 - 0s - loss: 0.2597 - mean_squared_error: 0.2597 - val_loss: 0.2787 - val_mean_squared_error: 0.2787 - 72ms/epoch - 8ms/step
# Epoch 48/64
# 9/9 - 0s - loss: 0.2611 - mean_squared_error: 0.2611 - val_loss: 0.2832 - val_mean_squared_error: 0.2832 - 70ms/epoch - 8ms/step
# Epoch 49/64
# 9/9 - 0s - loss: 0.2570 - mean_squared_error: 0.2570 - val_loss: 0.2897 - val_mean_squared_error: 0.2897 - 70ms/epoch - 8ms/step
# Epoch 50/64
# 9/9 - 0s - loss: 0.2583 - mean_squared_error: 0.2583 - val_loss: 0.2904 - val_mean_squared_error: 0.2904 - 69ms/epoch - 8ms/step
# Epoch 51/64
# 9/9 - 0s - loss: 0.2636 - mean_squared_error: 0.2636 - val_loss: 0.2908 - val_mean_squared_error: 0.2908 - 70ms/epoch - 8ms/step
# Epoch 52/64
# 9/9 - 0s - loss: 0.2646 - mean_squared_error: 0.2646 - val_loss: 0.2950 - val_mean_squared_error: 0.2950 - 71ms/epoch - 8ms/step
# Epoch 53/64
# 9/9 - 0s - loss: 0.2557 - mean_squared_error: 0.2557 - val_loss: 0.2816 - val_mean_squared_error: 0.2816 - 73ms/epoch - 8ms/step
# Epoch 54/64
# 9/9 - 0s - loss: 0.2558 - mean_squared_error: 0.2558 - val_loss: 0.2831 - val_mean_squared_error: 0.2831 - 69ms/epoch - 8ms/step
# Epoch 55/64
# 9/9 - 0s - loss: 0.2539 - mean_squared_error: 0.2539 - val_loss: 0.2924 - val_mean_squared_error: 0.2924 - 69ms/epoch - 8ms/step
# Epoch 56/64
# 9/9 - 0s - loss: 0.2543 - mean_squared_error: 0.2543 - val_loss: 0.2966 - val_mean_squared_error: 0.2966 - 70ms/epoch - 8ms/step
# Epoch 57/64
# 9/9 - 0s - loss: 0.2493 - mean_squared_error: 0.2493 - val_loss: 0.2853 - val_mean_squared_error: 0.2853 - 67ms/epoch - 7ms/step
# Epoch 58/64
# 9/9 - 0s - loss: 0.2518 - mean_squared_error: 0.2518 - val_loss: 0.2903 - val_mean_squared_error: 0.2903 - 70ms/epoch - 8ms/step
# Epoch 59/64
# 9/9 - 0s - loss: 0.2469 - mean_squared_error: 0.2469 - val_loss: 0.2866 - val_mean_squared_error: 0.2866 - 72ms/epoch - 8ms/step
# Epoch 60/64
# 9/9 - 0s - loss: 0.2518 - mean_squared_error: 0.2518 - val_loss: 0.2845 - val_mean_squared_error: 0.2845 - 70ms/epoch - 8ms/step
# Epoch 61/64
# 9/9 - 0s - loss: 0.2500 - mean_squared_error: 0.2500 - val_loss: 0.2897 - val_mean_squared_error: 0.2897 - 70ms/epoch - 8ms/step
# Epoch 62/64
# 9/9 - 0s - loss: 0.2445 - mean_squared_error: 0.2445 - val_loss: 0.2872 - val_mean_squared_error: 0.2872 - 68ms/epoch - 8ms/step
# Epoch 63/64
# 9/9 - 0s - loss: 0.2466 - mean_squared_error: 0.2466 - val_loss: 0.2852 - val_mean_squared_error: 0.2852 - 72ms/epoch - 8ms/step
# Epoch 64/64
# 9/9 - 0s - loss: 0.2447 - mean_squared_error: 0.2447 - val_loss: 0.3016 - val_mean_squared_error: 0.3016 - 69ms/epoch - 8ms/step

# %%
y_pred = classifier.predict(X_test_scaled)
# Out:
# 10/10 [==============================] - 0s 5ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print(mean_squared_error(y_test_scaled,y_pred))
print(mean_absolute_error(y_test_scaled,y_pred))
# Out:
# 0.28003651557974385
# 0.4060905210452799

# %%
y_test_flatten = y_test_scaled.flatten()
y_pred_flatten = y_pred.flatten()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test_flatten, y=y_pred_flatten)
plt.title('True Values vs Predicted Values')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.show()
